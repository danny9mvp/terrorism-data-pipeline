# %%
import pyspark
import pyspark.sql.functions as F

# %%
departments_geo_by_total_crimes_df = spark.read.table("departments_geo_by_total_crimes")

# %%
departments_geo_by_total_crimes_df.show(10)

# %%
top_departments_by_total_crimes_df = spark.read.table("top_departments_by_total_crimes")

# %%
display(top_departments_by_total_crimes_df)

# %%
min_max_total_crimes_by_year = spark.read.table("min_max_total_crimes_by_year").sample(False, 0.1)
display(min_max_total_crimes_by_year)
